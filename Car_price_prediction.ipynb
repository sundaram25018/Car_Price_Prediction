# %% [markdown]
# <a href="https://colab.research.google.com/github/sundaram25018/Car_Price_Prediction/blob/main/Car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/cardekho.csv")

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.isnull().sum()
# Out:
# name                    0
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    221
# engine                221
# max_power             215
# seats                 221
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                8128 non-null   object
#  1   year                8128 non-null   int64
#  2   selling_price       8128 non-null   int64
#  3   km_driven           8128 non-null   int64
#  4   fuel                8128 non-null   object
#  5   seller_type         8128 non-null   object
#  6   transmission        8128 non-null   object
#  7   owner               8128 non-null   object
#  8   mileage(km/ltr/kg)  7907 non-null   float64
#  9   engine              7907 non-null   float64
#  10  max_power           7913 non-null   object
#  11  seats               7907 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 762.1+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven  mileage(km/ltr/kg)  \
# count  8128.000000   8.128000e+03  8.128000e+03         7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04           19.418783
# std       4.044249   8.062534e+05  5.655055e+04            4.037145
# min    1983.000000   2.999900e+04  1.000000e+00            0.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04           16.780000
# 50%    2015.000000   4.500000e+05  6.000000e+04           19.300000
# 75%    2017.000000   6.750000e+05  9.800000e+04           22.320000
# max    2020.000000   1.000000e+07  2.360457e+06           42.000000
#
#             engine        seats
# count  7907.000000  7907.000000
# mean   1458.625016     5.416719
# std     503.916303     0.959588
# min     624.000000     2.000000
# 25%    1197.000000     5.000000
# 50%    1248.000000     5.000000
# 75%    1582.000000     5.000000
# max    3604.000000    14.000000

# %%
df.dtypes
# Out:
# name                   object
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                   object
# seller_type            object
# transmission           object
# owner                  object
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power              object
# seats                 float64
# dtype: object

# %%
def convert_float(x):
    try:
        return float(x)
    except:
        return np.nan

# %%
df['max_power'] = df['max_power'].apply(convert_float)

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.dtypes
# Out:
# name                   object
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                   object
# seller_type            object
# transmission           object
# owner                  object
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power             float64
# seats                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# name                    0
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    221
# engine                221
# max_power             216
# seats                 221
# dtype: int64

# %%
missing = ['mileage(km/ltr/kg)','engine', 'max_power','seats']
for i in missing:
  df[i] = df[i].fillna(df[i].median(),inplace=True)

# %%
# prompt: missing = ['mileage(km/ltr/kg)','engine', 'max_power','seats']
# for i in missing:
#   df[i] = df[i].fillna(df[i].median(),inplace=True)  how to solve this error

missing = ['mileage(km/ltr/kg)','engine', 'max_power','seats']
for i in missing:
  df[i] = df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# name                  0
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             0
# seats                 0
# dtype: int64

# %%
df['name'].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
df['brand'] = df['name'].apply(lambda x: x.split(' ')[0])

# %%
car_brand = df['brand'].value_counts().reset_index()

# %%
car_brand
# Out:
#             brand  count
# 0          Maruti   2448
# 1         Hyundai   1415
# 2        Mahindra    772
# 3            Tata    734
# 4          Toyota    488
# 5           Honda    467
# 6            Ford    397
# 7       Chevrolet    230
# 8         Renault    228
# 9      Volkswagen    186
# 10            BMW    120
# 11          Skoda    105
# 12         Nissan     81
# 13         Jaguar     71
# 14          Volvo     67
# 15         Datsun     65
# 16  Mercedes-Benz     54
# 17           Fiat     47
# 18           Audi     40
# 19          Lexus     34
# 20           Jeep     31
# 21     Mitsubishi     14
# 22          Force      6
# 23           Land      6
# 24          Isuzu      5
# 25            Kia      4
# 26     Ambassador      4
# 27         Daewoo      3
# 28             MG      3
# 29          Ashok      1
# 30           Opel      1
# 31        Peugeot      1

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='brand', y='count', data=car_brand.head(10))
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.countplot(x='owner', data=df)
plt.title('Owner type')

plt.subplot(1, 2, 2)
sns.countplot(x='fuel', data=df)
plt.title('Fuel Type')




plt.tight_layout()
plt.show()

# %%
# prompt: plot the graph side by side

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.countplot(x='seller_type', data=df)
plt.title('seller_type')

plt.subplot(1, 2, 2)
sns.countplot(x='transmission', data=df)
plt.title('transmission Type')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
# 3  Individual       Manual   First Owner               23.00  1396.0
# 4  Individual       Manual   First Owner               16.10  1298.0
#
#    max_power  seats    brand
# 0      74.00    5.0   Maruti
# 1     103.52    5.0    Skoda
# ...

# %%
numericals = ["engine", "max_power", "seats", "km_driven", "selling_price"]
sns.pairplot(df, vars=numericals)
sns.pairplot(df, vars=numericals)
plt.show()

# %%
corr = df[numericals].corr()
sns.heatmap(corr, annot=True, cmap="rainbow")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='year', y='selling_price', data=df)
# Out:
# <Axes: xlabel='year', ylabel='selling_price'>

# %%
categoricals = ["brand", "fuel", "seller_type", "transmission", "owner"]

# %%
def plot(df, name, nums, axes):
    group = df.groupby(name)
    mean = group[nums].mean()
    sns.barplot(x=mean.index, y=mean, ax=axes)
    for container in axes.containers:
        axes.bar_label(container)
    axes.set_xticklabels(axes.get_xticklabels(), rotation=90)

# %%
for i in categoricals:
    fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(20, 7))
    for j, k in enumerate(numericals):
        plot(df, i, k, axes[j])
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
# <ipython-input-57-fe1df7d1e343>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
for i in categoricals:
    fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(24, 7))
    for j, k in enumerate(numericals):
        sns.kdeplot(df, x=k, hue=i, ax=axes[j])
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-114-a2cf52b9b141>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df, x=k, hue=i, ax=axes[j])
# <ipython-input-114-a2cf52b9b141>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df, x=k, hue=i, ax=axes[j])
# <ipython-input-114-a2cf52b9b141>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df, x=k, hue=i, ax=axes[j])
# <ipython-input-114-a2cf52b9b141>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df, x=k, hue=i, ax=axes[j])
# <ipython-input-114-a2cf52b9b141>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df, x=k, hue=i, ax=axes[j])
# ...

# %%
for i in categoricals:
    fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(24, 7))
    for j, k in enumerate(numericals):
        sns.boxplot(df, y=k, x=i, ax=axes[j])
        axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-115-76e15c9cbc4e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
# <ipython-input-115-76e15c9cbc4e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
# <ipython-input-115-76e15c9cbc4e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
# <ipython-input-115-76e15c9cbc4e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
# <ipython-input-115-76e15c9cbc4e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in categoricals:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     1
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2         Honda City 2017-2020 EXi  2006         158000     140000     3
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4           Maruti Swift VXI BSIII  2007         130000     120000     3
# ...                            ...   ...            ...        ...   ...
# 8123             Hyundai i20 Magna  2013         320000     110000     3
# 8124         Hyundai Verna CRDi SX  2007         135000     119000     1
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000     1
# 8126               Tata Indigo CR4  2013         290000      25000     1
# 8127               Tata Indigo CR4  2013         290000      25000     1
#
#       seller_type  transmission  owner  mileage(km/ltr/kg)  engine  max_power  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
data = df[categoricals+["year"]+numericals].values

# %%
data
# Out:
# array([[2.000e+01, 1.000e+00, 1.000e+00, ..., 5.000e+00, 1.455e+05,
#         4.500e+05],
#        [2.700e+01, 1.000e+00, 1.000e+00, ..., 5.000e+00, 1.200e+05,
#         3.700e+05],
#        [1.000e+01, 3.000e+00, 1.000e+00, ..., 5.000e+00, 1.400e+05,
#         1.580e+05],
#        ...,
#        [2.000e+01, 1.000e+00, 1.000e+00, ..., 5.000e+00, 1.200e+05,
#         3.820e+05],
#        [2.800e+01, 1.000e+00, 1.000e+00, ..., 5.000e+00, 2.500e+04,
#         2.900e+05],
#        [2.800e+01, 1.000e+00, 1.000e+00, ..., 5.000e+00, 2.500e+04,
#         2.900e+05]])

# %%
from sklearn.preprocessing import MinMaxScaler
data = df[categoricals+["year"]+numericals].values
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
data
# Out:
# array([[0.64516129, 0.33333333, 0.5       , ..., 0.25      , 0.06164021,
#         0.04212648],
#        [0.87096774, 0.33333333, 0.5       , ..., 0.25      , 0.05083721,
#         0.0341024 ],
#        [0.32258065, 1.        , 0.5       , ..., 0.25      , 0.05931015,
#         0.01283861],
#        ...,
#        [0.64516129, 0.33333333, 0.5       , ..., 0.25      , 0.05083721,
#         0.03530601],
#        [0.90322581, 0.33333333, 0.5       , ..., 0.25      , 0.01059075,
#         0.02607833],
#        [0.90322581, 0.33333333, 0.5       , ..., 0.25      , 0.01059075,
#         0.02607833]])

# %%
from sklearn.model_selection import train_test_split
x = data[:, :-1]
y = data[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %%
def training(model):
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    r2 = r2_score(y_test, pred)
    mse = mean_squared_error(y_test, pred)
    print("MSE: ", mse)
    print("r2: ", r2)
    return r2, mse

# %%
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
rfr = RandomForestRegressor()
etr = ExtraTreesRegressor()
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()
lnr = LinearRegression()
xgb = XGBRegressor()

models = [rfr, etr, abr, gbr, lnr, xgb]
names = ["Random Forest", "Extra Trees", "Ada Boost",
        "Gradient Boosting", "Linear Regression", "XGBoost"]

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2s, mses = [], []
for i, j in zip(models, names):
    print("*"*30, "\n", j)
    r2, mse = training(i)
    r2s += [r2]
    mses += [mse]
    print("\n\n")
# Out:
# ******************************
#  Random Forest
# MSE:  0.00021334446259590564
# r2:  0.9676473848364028
#
#
#
# ******************************
#  Extra Trees
# MSE:  0.000195622991719328
# r2:  0.9703347568001587
#
#
#
# ******************************
#  Ada Boost
# MSE:  0.0019037762101894874
# r2:  0.711301908957753
#
#
#
# ******************************
#  Gradient Boosting
# MSE:  0.0002672366143214238
# r2:  0.9594749109699667
#
#
#
# ******************************
#  Linear Regression
# MSE:  0.0020787504356633677
# r2:  0.6847679473473822
#
#
#
# ******************************
#  XGBoost
# MSE:  0.000182028437487149
# r2:  0.9723963026028609

# %% [markdown]
# Conclusion¶
# The tree-based ensemble methods (Random Forest, Extra Trees, and XGBoost) show the best performance in terms of both MSE and 𝑅2 . They effectively capture the variance in the target variable and provide accurate predictions.
#
# Extra Trees and Random Forest have the best performance metrics overall, with Extra Trees slightly outperforming Random Forest.
#
# Gradient Boosting also performs well, though slightly behind Extra Trees and Random Forest.
#
# XGBoost performs similarly to Gradient Boosting, slightly better in some cases. AdaBoost and Linear Regression perform significantly worse than the other models, with higher MSE and lower 𝑅2 scores.

# %%
# prompt: how to pridict

# Use the best performing model (e.g., Extra Trees) to make predictions on new data
model = ExtraTreesRegressor()
# Assuming x_train has the correct number of features (10) for training
model.fit(x_train, y_train)

# Prepare new data for prediction, ensure it has the same number of features as the training data
# Assuming 'all_features' is a list of all column names used during training
all_features = categoricals + numericals
new_data = df[all_features].iloc[0].values
# Reshape the data to a 2D array for prediction
new_data = new_data.reshape(1, -1)

# Check if the scaler was fitted on the correct number of features
if scaler.n_features_in_ != new_data.shape[1]:
    print("Warning: Number of features in new data does not match the scaler. Refitting scaler.")
    scaler.fit(df[all_features]) # Refit the scaler on the correct features

new_data = scaler.transform(new_data)

# Predict the selling price
predicted_price = model.predict(new_data)[0]

# Print the predicted price
print("Predicted Selling Price:", predicted_price)
# Out:
# ...
# Predicted Selling Price: 0.017461481698948674
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
dt = pd.DataFrame({"r2": r2s, "mse": mses}, index=names)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 7))
dt = dt.sort_values("r2", ascending=False)
sns.barplot(x=dt.index, y=dt.iloc[:, 0], ax=axes[0])
for container in axes[0].containers:
    axes[0].bar_label(container)
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

dt = dt.sort_values("mse", ascending=True)
sns.barplot(x=dt.index, y=dt.iloc[:, 1], ax=axes[1])
for container in axes[1].containers:
    axes[1].bar_label(container)
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-131-c1e62d6603c3>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# <ipython-input-131-c1e62d6603c3>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)
